# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import matplotlib.dates as mdates
import seaborn as sns
import sklearn.metrics as sm

from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import learning_curve
from sklearn.model_selection import LearningCurveDisplay
from sklearn.model_selection import validation_curve
from sklearn.model_selection import RandomizedSearchCV

from yellowbrick.model_selection import ValidationCurve
from yellowbrick.model_selection import learning_curve

from statsmodels.tsa.stattools import adfuller

import requests
from datetime import datetime, timedelta

# %%
network = 'eth'
usdc_usdt_paddr = '0x3416cf6c708da44db2624d63ea0aaef7113527c6'
wbtc_usdc_paddr = '0x99ac8ca7087fa4a2a1fb6357269965a2014abc35'
uni_weth_paddr = '0x8f0cb37cdff37e004e0088f563e5fe39e05ccc5b'

parameters = f'{network}/pools/{usdc_usdt_paddr}'
specificity = f'{1}'

#URL with your specifications
url = f'https://api.geckoterminal.com/api/v2/networks/{parameters}/ohlcv/day?aggregate={specificity}'
response = requests.get(url)
print(f'URL: {url}')
data = response.json()

#Turning into pandas dataframe, turning the date value into datetime format, making it the index
data = data['data']['attributes']['ohlcv_list']
df = pd.DataFrame(data, columns=['Date', 'Open', 'Close', 'High', 'Low', 'Volume'])
df['Date'] = pd.to_datetime(df['Date'], unit = 's')
df.set_index('Date', inplace = True)

raw_df = df
raw_df
# Out:
# URL: https://api.geckoterminal.com/api/v2/networks/eth/pools/0x3416cf6c708da44db2624d63ea0aaef7113527c6/ohlcv/day?aggregate=1
#                 Open     Close      High       Low        Volume
# Date
# 2024-06-02  1.002311  1.003658  0.997258  1.000719  1.183730e+07
# 2024-06-01  0.998777  1.003445  0.997118  1.002311  2.623767e+07
# 2024-05-31  0.999260  1.003706  0.996914  0.998777  6.849573e+07
# 2024-05-30  1.003089  1.003636  0.996373  0.999260  6.683083e+07
# 2024-05-29  1.003585  1.003934  0.997036  1.003089  5.039566e+07
# ...              ...       ...       ...       ...           ...
# 2024-02-28  1.001401  1.003569  0.994650  0.997353  1.067322e+08
# 2024-02-27  1.001050  1.003201  0.994197  1.001401  8.535529e+07
# 2024-02-26  0.998081  1.003457  0.995704  1.001050  9.736802e+07
# 2024-02-25  0.998952  1.003176  0.996779  0.998081  2.260795e+07
# 2024-02-24  0.999584  1.003501  0.992614  0.998952  1.589684e+07
#
# [100 rows x 5 columns]

# %%
# # Collect and clean the data
# raw_df = pd.read_csv('./stock_prediction/Dataset/google-stock-dataset.csv')
# raw_df = raw_df.drop(['Unnamed: 0', 'Adj Close'], axis=1)
# raw_df.set_index("Date", inplace=True)
# raw_df

# %%
# Check for empty value
raw_df.isna().sum()
# Out:
# Open      0
# Close     0
# High      0
# Low       0
# Volume    0
# dtype: int64

# %%
# Show the data visually
raw_df.plot(y="Close")
plt.legend(['Close value'])
plt.xticks(rotation=45)
# Out:
# (array([19777, 19783, 19814, 19844, 19875, 19876]),
#  [Text(19777, 0, ''),
#   Text(19783, 0, 'Mar\n2024'),
#   Text(19814, 0, 'Apr'),
#   Text(19844, 0, 'May'),
#   Text(19875, 0, 'Jun'),
#   Text(19876, 0, '')])

# %%
raw_df[['Open', 'High', 'Low', 'Close', 'Volume']].plot(subplots=True, figsize=(10, 15), xticks=None, kind='line', legend=None)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
# Test for stationary using ADF (Augmented Dicket-Fuller Test)
def is_stationary(df):
    result = adfuller(df)
    test_statistic = result[0]
    p_value = result[1]
    ciritcal_values = result[4]
    
    for key, value in result[4].items():
        if test_statistic > value:
            return False
    return True

# Converting non-stationary to stationary
def convert_to_stationary(df):
    df_diff = df.diff().dropna()
    return df_diff

# Revert back to non stationary data
def revert_to_non_stationary(init, stat_df):
    df_rev_diff = np.r_[init, stat_df].cumsum()
    #df_square = np.square(df_rev_diff)
    return df_rev_diff

# %%
# Test for stationary data
for col in list(raw_df):
    print('Is stationary:', is_stationary(raw_df[col]))
# Out:
# Is stationary: True
# Is stationary: True
# Is stationary: True
# Is stationary: True
# Is stationary: True

# %%
# convert to stationary
# stat_df = pd.DataFrame()
# for col in list(raw_df):
#     if not is_stationary(raw_df[col]):
#         stat_df[col] = convert_to_stationary(raw_df[col])
#         continue
#     stat_df[col] = raw_df[col]

# for col in list(stat_df):
#     print('Is stationary:', is_stationary(stat_df[col]))
# Out:
# Is stationary: True
# Is stationary: True
# Is stationary: True
# Is stationary: True
# Is stationary: True

# %%
df.plot(subplots=True, figsize=(10, 10))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
sns.heatmap(df.corr(), robust=True, fmt='.2f', annot=True)
# Out:
# <Axes: >

# %%
#### PREPROCESSING ####
stat_df = df.dropna() # Drop missing data

# x_data = raw_df.iloc[:, raw_df.columns != 'Volume'].values
x_data = stat_df.drop(['Close'], axis=1).values
y_data = stat_df['Close'].values

# Scaling
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x_data)

# Divide into train and test datasets
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=0, shuffle=False)

y_data
# Out:
# array([1.00365776, 1.0034452 , 1.00370585, 1.00363641, 1.00393388,
#        1.00400046, 1.00793077, 1.00357998, 1.00324505, 1.00342477,
#        1.00737432, 1.00349026, 1.00616521, 1.00827904, 1.0030576 ,
#        1.00314277, 1.00452678, 1.00303776, 1.00333364, 1.00363482,
#        1.00544305, 1.00338679, 1.00341282, 1.00361104, 1.00427623,
#        1.00400441, 1.00385209, 1.00419435, 1.00300966, 1.00302504,
#        1.00312501, 1.00400101, 1.00759258, 1.00416068, 1.00331577,
#        1.00343827, 1.00339845, 1.00337428, 1.0034237 , 1.00339803,
#        1.00289814, 1.00299699, 1.00309499, 1.00453618, 1.00838058,
#        1.00462801, 1.00387201, 1.00382137, 1.00753766, 1.00641206,
#        1.02198568, 1.00811544, 1.00314374, 1.0036159 , 1.0047615 ,
#        1.00325904, 1.00313302, 1.00301156, 1.00398259, 1.00345374,
#        1.00337918, 1.00375211, 1.00347936, 1.00325359, 1.00298986,
#        1.00308704, 1.00343395, 1.00335738, 1.01077966, 1.00353803,
#        1.00321506, 1.0082481 , 1.0045721 , 1.0035268 , 1.00838583,
#        1.01760865, 1.00865253, 1.00887466, 1.0194284 , 1.0189995 ,
#        1.0048345 , 1.00435635, 1.00799382, 1.00320318, 1.00239823,
#        1.00222247, 1.00378398, 1.00718183, 1.00483027, 1.00798557,
#        1.00846522, 1.00317159, 1.00282134, 1.00364942, 1.00370332,
#        1.00356925, 1.00320085, 1.00345738, 1.00317632, 1.00350114])

# %%
# # Use the random grid to search for best hyperparameters (Using 3-folds cross validation). It takes too much time, so I commented it out.

# grid_rf = {
# 'n_estimators': [int(x) for x in np.linspace(start=200, stop=2000, num=100)],  
# 'max_depth': [int(x) for x in np.linspace(10, 110, num=11)], 
# 'min_samples_split': [2, 5, 10], 
# 'min_samples_leaf': [1, 2, 4],  
# 'bootstrap': [True, False],
# }

# rscv = RandomizedSearchCV(estimator=RandomForestRegressor(), param_distributions=grid_rf, cv=3, n_jobs=-1, verbose=2, n_iter=200)

# # Fit the random search model
# rscv_fit = rscv.fit(x_train, y_train)

# best_parameters = rscv_fit.best_params_
# print(best_parameters)

# # ## RESULT (41m 54.7s) ###
# # Fitting 3 folds for each of 200 candidates, totalling 600 fits
# # {'n_estimators': 763, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_depth': 20, 'bootstrap': True}

# %%
# Plot validation curve on paran 'n_estimators'
# viz = ValidationCurve(RandomForestRegressor(), param_name="n_estimators", param_range=np.arange(200, 2000, 100), cv=3, scoring="r2")
# viz.fit(x_scaled, y_data)
# viz.show()

# %%
model = RandomForestRegressor(n_estimators=763, min_samples_split=5, min_samples_leaf=4, max_depth=20, bootstrap=True)

# %%
# Train the model
model.fit(x_train, y_train) # Training the model
# Out:
# RandomForestRegressor(max_depth=20, min_samples_leaf=4, min_samples_split=5,
#                       n_estimators=763)

# %%
# Draw learning curve for training set
LearningCurveDisplay.from_estimator(model, x_train, y_train, score_type='both')

# %%
# Test the model
y_predict_train = model.predict(x_train)
y_predict = model.predict(x_test)
print('The model score is:', model.score(x_test, y_predict))
# Out:
# The model score is: 1.0

# %%
print(f'X_TRAIN: {x_train}')
print(f'Y_PREDICT_TRAIN: {y_predict_train}')
print(f'X_TEST: {x_test}')
print(f'Y_PREDICT_TEST: {y_predict}')
# Out:
# X_TRAIN: [[1.00231116e+00 9.97257987e-01 1.00071924e+00 1.18372970e+07]
#  [9.98777468e-01 9.97118031e-01 1.00231116e+00 2.62376705e+07]
#  [9.99260335e-01 9.96914469e-01 9.98777468e-01 6.84957316e+07]
#  [1.00308930e+00 9.96372716e-01 9.99260335e-01 6.68308287e+07]
#  [1.00358460e+00 9.97035595e-01 1.00308930e+00 5.03956610e+07]
#  [9.99336728e-01 9.96990231e-01 1.00358460e+00 5.62908400e+07]
#  [1.00067769e+00 9.96950943e-01 9.99336728e-01 7.16275940e+07]
#  [9.98182389e-01 9.96956458e-01 1.00067769e+00 3.99599893e+07]
#  [1.00091445e+00 9.96856537e-01 9.98182389e-01 2.00614596e+07]
#  [9.97491637e-01 9.96450118e-01 1.00091445e+00 8.72264366e+07]
#  [1.00177340e+00 9.81263713e-01 9.97491637e-01 1.71535302e+08]
#  [1.00285966e+00 9.96612731e-01 1.00177340e+00 5.26143981e+07]
#  [9.98459039e-01 9.94297892e-01 1.00285966e+00 1.67339949e+08]
#  [1.00032794e+00 9.81847749e-01 9.98459039e-01 1.20112231e+08]
#  [9.98852480e-01 9.96867414e-01 1.00032794e+00 3.91844672e+07]
#  [9.97123304e-01 9.96699898e-01 9.98852480e-01 3.55851355e+07]
#  [9.99580684e-01 9.96656630e-01 9.97123304e-01 5.25109052e+07]
#  [9.99792783e-01 9.96588465e-01 9.99580684e-01 4.70058717e+07]
#  [1.00265112e+00 9.96562856e-01 9.99792783e-01 1.14686379e+08]
#  [1.00016860e+00 9.96919887e-01 1.00265112e+00 4.26164917e+07]
#  [9.99499769e-01 9.96864126e-01 1.00016860e+00 5.57276366e+07]
#  [1.00117365e+00 9.97259015e-01 9.99499769e-01 1.06049522e+07]
#  [9.99190902e-01 9.96966129e-01 1.00117365e+00 2.42568586e+07]
#  [9.99843415e-01 9.91786689e-01 9.99190902e-01 5.79809411e+07]
#  [9.98595060e-01 9.96623805e-01 9.99843415e-01 4.98518197e+07]
#  [1.00168478e+00 9.96517352e-01 9.98595060e-01 2.31476391e+07]
#  [1.00201363e+00 9.96376959e-01 1.00168478e+00 3.57781257e+07]
#  [9.99577072e-01 9.96741005e-01 1.00201363e+00 3.50408413e+07]
#  [1.00060279e+00 9.96847041e-01 9.99577072e-01 3.38217332e+07]
#  [1.00187594e+00 9.96653146e-01 1.00060279e+00 3.79384067e+07]
#  [1.00128016e+00 9.96708413e-01 1.00187594e+00 6.69757109e+07]
#  [1.00139062e+00 9.96810033e-01 1.00128016e+00 7.71080231e+07]
#  [1.00268933e+00 9.75410383e-01 1.00139062e+00 8.47183894e+07]
#  [1.00210291e+00 9.96741545e-01 1.00268933e+00 9.59309630e+07]
#  [9.99415706e-01 9.96944406e-01 1.00210291e+00 5.32771698e+07]
#  [9.98879621e-01 9.97196146e-01 9.99415706e-01 2.64080829e+07]
#  [9.99478809e-01 9.96717304e-01 9.98879621e-01 3.62050090e+07]
#  [1.00139973e+00 9.97077352e-01 9.99478809e-01 4.93987985e+07]
#  [9.98589727e-01 9.97006406e-01 1.00139973e+00 5.43273379e+07]
#  [9.97944768e-01 9.96790181e-01 9.98589727e-01 8.60564101e+07]
#  [1.00117573e+00 9.96164712e-01 9.97944768e-01 4.59462306e+07]
#  [1.00053724e+00 9.96723550e-01 1.00117573e+00 4.79343054e+07]
#  [9.99406111e-01 9.96569664e-01 1.00053724e+00 1.75339391e+07]
#  [1.00170960e+00 9.96637735e-01 9.99406111e-01 1.77539694e+07]
#  [1.00121565e+00 9.94533607e-01 1.00170960e+00 8.80330529e+07]
#  [1.00056932e+00 9.96481589e-01 1.00121565e+00 4.96652978e+07]
#  [1.00092109e+00 9.94862767e-01 1.00056932e+00 5.81397719e+07]
#  [1.00014967e+00 9.96405764e-01 1.00092109e+00 9.07110195e+07]
#  [1.00100492e+00 9.96235083e-01 1.00014967e+00 7.65589778e+07]
#  [1.00281433e+00 9.94522389e-01 1.00100492e+00 1.03040416e+08]
#  [9.99321179e-01 9.76946859e-01 1.00281433e+00 1.63869155e+08]
#  [9.99224692e-01 9.77836203e-01 9.99321179e-01 1.15883683e+08]
#  [9.99515650e-01 9.96872416e-01 9.99224692e-01 7.56439740e+07]
#  [9.99070573e-01 9.92404619e-01 9.99515650e-01 6.68512963e+07]
#  [1.00284580e+00 9.96783555e-01 9.99070573e-01 8.78199283e+07]
#  [9.97975984e-01 9.90980825e-01 1.00284580e+00 1.08322802e+08]
#  [1.00285517e+00 9.96433713e-01 9.97975984e-01 5.46599829e+07]
#  [1.00053614e+00 9.96744670e-01 1.00285517e+00 2.13296833e+07]
#  [9.99269052e-01 9.96481998e-01 1.00053614e+00 5.49804962e+07]
#  [1.00130762e+00 9.96486276e-01 9.99269052e-01 6.96060289e+07]
#  [1.00116823e+00 9.96567300e-01 1.00130762e+00 1.00845146e+08]
#  [9.99133291e-01 9.90640617e-01 1.00116823e+00 1.34266807e+08]
#  [9.97683690e-01 9.88825644e-01 9.99133291e-01 7.08932861e+07]
#  [1.00061851e+00 9.96649526e-01 9.97683690e-01 5.89570958e+07]
#  [1.00038516e+00 9.96418970e-01 1.00061851e+00 2.27321145e+07]
#  [1.00225681e+00 9.70698741e-01 1.00038516e+00 4.03858227e+07]
#  [9.98771197e-01 9.96774868e-01 1.00225681e+00 5.21442399e+07]
#  [1.00152602e+00 9.96500010e-01 9.98771197e-01 5.78710841e+07]
#  [1.00091323e+00 9.96133652e-01 1.00152602e+00 7.31477673e+07]
#  [1.00132209e+00 9.96302763e-01 1.00091323e+00 5.24459547e+07]
#  [1.00105501e+00 9.96621480e-01 1.00132209e+00 2.42141842e+07]
#  [9.98596419e-01 9.88513964e-01 1.00105501e+00 3.14629248e+07]
#  [1.00040185e+00 9.93756716e-01 9.98596419e-01 4.78585696e+07]
#  [1.00185778e+00 9.96291744e-01 1.00040185e+00 5.47022700e+07]
#  [1.00080392e+00 9.95828324e-01 1.00185778e+00 9.62550156e+07]
#  [1.00168736e+00 9.81660208e-01 1.00080392e+00 1.17532681e+08]
#  [1.00134640e+00 9.88907520e-01 1.00168736e+00 6.73708185e+07]
#  [1.00134670e+00 9.95900763e-01 1.00134640e+00 4.92534706e+07]
#  [9.99715381e-01 9.84648382e-01 1.00134670e+00 5.88896288e+07]
#  [1.00038531e+00 9.79096773e-01 9.99715381e-01 1.85262950e+08]]
# Y_PREDICT_TRAIN: [1.00366393 1.00355127 1.0038735  1.00363803 1.00388745 1.00394998
#  1.0046666  1.00350009 1.00337404 1.00392922 1.01185981 1.00368293
#  1.00690722 1.01178865 1.00332707 1.00337543 1.00395911 1.00334076
#  1.00434465 1.00352448 1.00415212 1.00350628 1.00349669 1.00449082
#  1.00393908 1.00362354 1.00362809 1.00353832 1.00326227 1.00344216
#  1.00357718 1.00439148 1.0117947  1.00424603 1.00378851 1.00351024
#  1.00341195 1.00371032 1.00379904 1.00405634 1.00469656 1.00330164
#  1.00333601 1.00368737 1.00755072 1.00385611 1.0057122  1.00404076
#  1.0057971  1.00667365 1.01306251 1.0115517  1.00428582 1.00443719
#  1.00441375 1.00597212 1.00360327 1.00335436 1.0038398  1.00369307
#  1.00409888 1.00611438 1.00546676 1.00361704 1.00325342 1.01056249
#  1.00376673 1.00356248 1.00733674 1.00385851 1.00335306 1.0073231
#  1.0048577  1.0038026  1.0075291  1.01239392 1.00769564 1.00701284
#  1.01158075 1.01231143]
# X_TEST: [[9.98386065e-01 9.94319472e-01 1.00038531e+00 1.07649595e+08]
#  [9.96211389e-01 9.95052190e-01 9.98386065e-01 9.72432310e+07]
#  [1.00140527e+00 9.91799996e-01 9.96211389e-01 1.09125972e+08]
#  [9.97293683e-01 9.95154251e-01 1.00140527e+00 9.51487753e+07]
#  [9.98575583e-01 9.95515440e-01 9.97293683e-01 5.29331186e+07]
#  [9.99413998e-01 9.93787180e-01 9.98575583e-01 2.02155446e+07]
#  [9.97759318e-01 9.92543426e-01 9.99413998e-01 9.24162132e+07]
#  [9.98451698e-01 9.95261179e-01 9.97759318e-01 9.34741966e+07]
#  [1.00257638e+00 9.95731692e-01 9.98451698e-01 1.51537326e+08]
#  [1.00293634e+00 9.92817179e-01 1.00257638e+00 2.22442544e+08]
#  [9.97483653e-01 9.95933424e-01 1.00293634e+00 7.62073721e+07]
#  [9.96780000e-01 9.96098512e-01 9.97483653e-01 6.92809868e+07]
#  [1.00214762e+00 9.96233500e-01 9.96780000e-01 3.05826147e+07]
#  [1.00075518e+00 9.95010572e-01 1.00214762e+00 1.10330676e+08]
#  [9.97352811e-01 9.95686686e-01 1.00075518e+00 2.07254310e+08]
#  [1.00140060e+00 9.94649705e-01 9.97352811e-01 1.06732188e+08]
#  [1.00105047e+00 9.94197137e-01 1.00140060e+00 8.53552852e+07]
#  [9.98080830e-01 9.95703869e-01 1.00105047e+00 9.73680225e+07]
#  [9.98952311e-01 9.96779076e-01 9.98080830e-01 2.26079549e+07]
#  [9.99583635e-01 9.92614380e-01 9.98952311e-01 1.58968447e+07]]
# Y_PREDICT_TEST: [1.00517796 1.00512186 1.00583202 1.00632366 1.00489786 1.00448023
#  1.00473793 1.0051245  1.00720694 1.00774187 1.00658621 1.00484384
#  1.00469838 1.00741246 1.00642977 1.00620096 1.00741274 1.00590458
#  1.00338793 1.004403  ]

# %%
# Make the prediction
# x-axis
x_dates = []
predicted_dates = stat_df.index[x_train.shape[0]:]
# restore_point = raw_df['Close'][predicted_dates[0]]
for d in predicted_dates:
    x_dates.append(mdates.date2num(d))

# %%
# y_test_restored = revert_to_non_stationary(restore_point, y_test)[1:]
# y_predict_restored = revert_to_non_stationary(restore_point, y_predict)[1:]

# Plot the test predictions
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%m-%Y'))
plt.xticks(rotation=45)

plt.plot(x_dates, y_test, color='blue')
plt.plot(x_dates, y_predict, color='red', linestyle='--')
plt.gca().legend(('Actual', 'Prediction'))
plt.show()

# %%
print("DONE")
# Out:
# DONE
